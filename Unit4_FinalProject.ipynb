# %% [markdown]
# # Let's map some earthquakes!
#
# Use this notebook to complete your final project for unit 4. You'll create a dataframe for the data you downloaded and then plot the earthquakes using latitude and longitude. You'll also create functions to make your code more efficient.

# %% [markdown]
# Import the libraries you need here:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# This code adds an image behind your plot:

# %%
image = plt.imread("plates.png")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

# %% [markdown]
# Create your data frame:

# %%
df = pd.read_csv("Earthquake Results in Central Pacific - results.csv")
df.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE  SECOND  FOCAL_DEPTH  \
# 0  9925          Tsu  1900    1.0  10.0   NaN     NaN     NaN          NaN
# 1  2567          NaN  1900    1.0  14.0   NaN     NaN     NaN          NaN
# 2  2575          NaN  1900    7.0  29.0   6.0    59.0     NaN         33.0
# 3  6232          Tsu  1900    9.0  10.0  21.0    30.0     NaN          NaN
# 4  6234          Tsu  1900    9.0  17.0  21.0    45.0     NaN          NaN
#
#    EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 0         NaN               ...                           NaN
# 1         NaN               ...                           NaN
# 2         7.6               ...                           NaN
# 3         6.6               ...                           NaN
# 4         7.1               ...                           NaN
#
#    TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 0                        NaN             NaN                         NaN
# 1                        NaN             NaN                         NaN
# 2                        NaN             NaN                         NaN
# 3                        NaN             NaN                         NaN
# 4                        NaN             NaN                         NaN
#
#    TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 0                            NaN                       NaN
# 1                            NaN                       2.0
# 2                            NaN                       NaN
# 3                            NaN                       1.0
# 4                            NaN                       NaN
#
#    TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#   TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 0                  NaN                              NaN
# 1                  NaN                              3.0
# 2                  NaN                              NaN
# 3                  NaN                              1.0
# 4                  NaN                              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# Try plotting your earthquakes!
# Hint: You will need to use the "LATITUDE" and "LONGITUDE" columns
#
# You will also need xlim and ylim to focus the map on your region. Use the following limits:
# - North America: xlim = (-180,-50), ylim = (0,90)
# - Central America: xlim = (-100,-70), ylim = (0,25)
# - South America: xlim = (-120,-20), ylim = (-60,20)
# - Africa: xlim = (-25,50), ylim = (-40,45)
# - Pacific: xlim = (80,180), ylim = (-70,30)

# %%
latitude= df["LATITUDE"]
longitude = df["LONGITUDE"]

# %%
image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

plt.scatter(longitude,latitude)
plt.xlim(80,180)
plt.ylim(-70,30)
plt.title("Central South Pacific Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Central Pacific Earthquakes on Earth.png")
plt.show()

# %% [markdown]
# Replace your (image = plt.imread("earth.jpg")) code with the following and see what happens:
# image = plt.imread("plates.png")
#
# What do you notice?

# %%
image = plt.imread("plates.png")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

plt.scatter(longitude,latitude, color = "yellow")
plt.xlim(80,180)
plt.ylim(-70,30)
plt.title("Central South Pacific Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Central Pacific Earthquakes with Plates.png")
plt.show()

# %% [markdown]
# ### Let's add some color (and functions)
# Next, you'll need to color code your points based on one of the characteristics in the data frame.
#
# First, create a function that takes the name of a column and a number of colors and returns list of intermediate values based on the number of colors you specify (these values will be the boundaries for conditionals later on).

# %%
#NOPE
mylist=[]
mylist2=[]
mylist3=[]
def colorFunc (column, num_color):
    new_column = column.dropna()
    boundary = (max(new_column)-min(new_column))/num_color
    for item in new_column:
        if item > boundary + min(new_column):
            mylist.append(item)
        elif item > boundary*2 + min(new_column):
            mylist2.append(item)
        else:
            mylist3.append(item)
colorFunc(df["EQ_PRIMARY"],3)
            
print(mylist)
print(mylist2)
print(mylist3)
# Out:
# [7.5999999999999996, 6.5999999999999996, 7.0999999999999996, 6.9000000000000004, 8.4000000000000004, 7.7999999999999998, 7.7999999999999998, 7.7999999999999998, 7.2999999999999998, 8.0999999999999996, 8.0, 8.0999999999999996, 6.5, 7.9000000000000004, 7.7999999999999998, 7.5, 8.4000000000000004, 7.5, 7.5, 7.5999999999999996, 6.5, 8.0, 7.2000000000000002, 7.7999999999999998, 7.7999999999999998, 7.2999999999999998, 7.5999999999999996, 7.4000000000000004, 7.7000000000000002, 7.9000000000000004, 7.4000000000000004, 7.5, 7.5, 6.5999999999999996, 7.5, 7.7999999999999998, 7.5999999999999996, 7.7000000000000002, 8.0, 6.0, 7.5, 7.9000000000000004, 7.9000000000000004, 7.2000000000000002, 8.0, 7.5, 6.7000000000000002, 6.2000000000000002, 7.7999999999999998, 7.7000000000000002, 7.5, 6.9000000000000004, 6.7999999999999998, 7.7999999999999998, 7.7000000000000002, 7.5, 7.5999999999999996, 7.0, 8.0999999999999996, 7.5, 8.0999999999999996, 7.5999999999999996, 7.5999999999999996, 6.0, 6.4000000000000004, 7.9000000000000004, 8.0999999999999996, 8.0999999999999996, 7.5, 7.2999999999999998, 6.5999999999999996, 6.4000000000000004, 8.0, 8.3000000000000007, 7.7000000000000002, 7.7999999999999998, 7.5, 7.5, 7.5, 8.3000000000000007, 8.0999999999999996, 7.4000000000000004, 8.3000000000000007, 8.0999999999999996, 7.7999999999999998, 6.9000000000000004, 7.7000000000000002, 7.7999999999999998, 6.2000000000000002, 7.5, 7.5, 7.5, 6.2999999999999998, 6.0, 6.2999999999999998, 7.2000000000000002, 5.5, 7.5, 7.2000000000000002, 7.2000000000000002, 8.3000000000000007, 6.5, 7.7999999999999998, 7.5, 7.2999999999999998, 7.5999999999999996, 6.7999999999999998, 6.2999999999999998, 7.2999999999999998, 7.5, 6.9000000000000004, 7.9000000000000004, 7.9000000000000004, 6.2999999999999998, 7.5, 7.0, 7.2999999999999998, 7.2000000000000002, 7.5, 6.0, 6.5, 6.5999999999999996, 6.5, 7.7000000000000002, 7.0999999999999996, 6.9000000000000004, 7.0, 7.4000000000000004, 7.7999999999999998, 7.7000000000000002, 6.2000000000000002, 7.4000000000000004, 7.9000000000000004, 6.7999999999999998, 7.5, 7.5, 7.9000000000000004, 7.5, 7.7999999999999998, 7.0999999999999996, 7.7999999999999998, 6.5, 7.5999999999999996, 7.9000000000000004, 7.7000000000000002, 8.0999
, 7.5, 7.2000000000000002, 8.5, 7.5, 7.5999999999999996, 7.7000000000000002, 7.9000000000000004, 8.0, 7.4000000000000004, 7.7999999999999998, 7.5, 8.0999999999999996, 7.5999999999999996, 8.0999999999999996, 7.9000000000000004, 7.5, 7.5999999999999996, 7.5999999999999996, 7.5, 7.5, 7.5, 7.5, 7.7999999999999998, 7.7000000000000002, 7.0999999999999996, 7.2999999999999998, 8.3000000000000007, 7.9000000000000004, 7.9000000000000004, 7.5, 7.5, 7.2000000000000002, 7.5999999999999996, 8.0999999999999996, 7.2999999999999998, 7.7999999999999998, 7.7000000000000002, 7.7999999999999998, 7.7999999999999998, 7.4000000000000004, 7.5, 7.5, 7.7999999999999998, 7.5999999999999996, 7.2999999999999998, 7.7000000000000002, 7.5, 7.5, 7.5, 7.5, 7.2999999999999998, 7.5999999999999996, 7.5, 7.7999999999999998, 7.2999999999999998, 7.7000000000000002, 7.5, 7.2999999999999998, 7.5, 7.5, 8.3000000000000007, 7.5, 7.5, 7.5999999999999996, 7.5999999999999996, 7.5999999999999996, 7.2999999999999998, 7.0999999999999996, 7.7999999999999998, 7.2000000000000002, 7.7999999999999998, 7.0999999999999996, 7.7000000000000002, 7.2999999999999998, 7.2999999999999998, 7.5999999999999996, 7.4000000000000004, 7.5, 7.5, 7.5, 7.4000000000000004, 7.7000000000000002, 7.5999999999999996, 7.0999999999999996, 7.2999999999999998, 7.5999999999999996, 7.5, 7.2999999999999998, 8.0999999999999996, 7.0999999999999996, 7.9000000000000004, 7.9000000000000004, 7.0999999999999996, 7.2000000000000002, 7.7999999999999998, 7.0999999999999996, 7.4000000000000004, 7.5, 7.5, 7.2000000000000002, 7.0999999999999996, 7.9000000000000004, 7.7000000000000002, 7.7999999999999998, 7.5999999999999996, 7.7999999999999998, 7.7999999999999998, 8.0, 7.0999999999999996, 8.0, 7.0999999999999996, 7.2999999999999998, 7.5999999999999996, 7.5999999999999996, 7.5, 8.0999999999999996, 7.2000000000000002, 8.0, 7.2000000000000002, 7.7000000000000002, 7.9000000000000004, 7.5, 7.5, 7.9000000000000004, 7.5999999999999996, 7.7000000000000002, 7.0999999999999996, 7.5, 7.7000000000000002, 7.5999999999999996, 7.5, 7.0999999999999996, 7.2000000000000002, 7.0999999999999996, 7.5999999999999996, 7.5999999999999996, 7.0999999999999996, 8.0999999999999996, 7.5999999999999996, 7.7000000000000002, 7.2999999999999998, 7.700000000000 ...

# %%
new =df["EQ_PRIMARY"].dropna()
print(min(new))
print(max(new))
# Out:
# 3.1
# 9.1

# %%
def colorFunc (column, num_color):
    mylist=[]
    new_column = column.dropna()
    boundary = (max(new_column)-min(new_column))/num_color
    num_temp= min(new_column)
    while len(mylist)<num_color:
        num_temp+=boundary
        mylist.append(num_temp)
    return mylist
    
colorFunc(df["EQ_PRIMARY"],10)
# Out:
# [3.7000000000000002,
#  4.2999999999999998,
#  4.8999999999999995,
#  5.4999999999999991,
#  6.0999999999999988,
#  6.6999999999999984,
#  7.299999999999998,
#  7.8999999999999977,
#  8.4999999999999982,
#  9.0999999999999979]

# %%
def Func(column, numColor):
    empty_list = []
    num_range = column.max()- column.min()
    interval = num_range/numColor
    while len(empty_list) < numColor:
           empty_list.append(column.min())

# %% [markdown]
# Next, you will make your own version of the colormap we used to color the stars in the astrophysics unit. You will need to make a list that contains a color for each value of the characteristic you have chosen. Think back to the climate change unit for ideas...
#
# You should create a function that takes the name of your characteristic column and a list of RGB value lists and creates a list of values for the "colormap".
#
# Hint: You will need to use the last function you created. You can call this function inside of your new function.

# %%
def rgbFunc (mylist, column):
    colors=[]
    for item in column: 
        if item <= mylist[0]:
            colors.append([255/255, 247/255, 247/255])
        elif item <= mylist[1]:
            colors.append([255/255, 212/255, 212/255])
        elif item <= mylist[2]:
            colors.append([255/255, 198/255, 198/255])
        elif item <= mylist[3]:
            colors.append([255/255, 178/255, 178/255])
        elif item <= mylist[4]:
            colors.append([255/255, 158/255, 158/255])
        elif item <= mylist[5]:
            colors.append([255/255, 140/255, 140/255])
        elif item <= mylist[6]:
            colors.append([255/255, 114/255, 114/255])
        elif item <= mylist[7]:
            colors.append([255/255, 99/255, 99/255])
        elif item <= mylist[8]:
            colors.append([255/255, 61/255, 61/255])
        elif item <= mylist[9]:
            colors.append([255/255,0/255,0/255])
    return colors

colormap =rgbFunc(colorFunc(new,10), new)

# %% [markdown]
# Next, plot your graph again, adding the argument c = your "colormap" to the scatterplot function:

# %%
# You will need to run this code again first
image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

plt.scatter(longitude,latitude, c=colormap)
plt.xlim(80,180)
plt.ylim(-70,30)
plt.title("Central South Pacific Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Central Pacific Earthquakes with Colormap on Earth.png")
plt.show()

# %%
image = plt.imread("plates.png")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

plt.scatter(longitude,latitude, c=colormap)
plt.xlim(80,180)
plt.ylim(-70,30)
plt.title("Central South Pacific Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Central Pacific Earthquakes with Colormap on Plates.png")
plt.show()

# %% [markdown]
# Replace your (image = plt.imread("earth.jpg")) code with the following and see what happens:
# image = plt.imread("plates.png")
#
# What do you notice?

# %% [markdown]
# ### Challenge:
# Change the size of your markers based on a second characteristic

# %%
colorFunc(df["DEATHS"],5)
# Out:
# [1200.8, 2400.5999999999999, 3600.3999999999996, 4800.1999999999998, 6000.0]

# %%
def sizeFunc (mylist, column):
    size=[]
    for item in column: 
        if item <= mylist[0]:
            size.append(10)
        elif item <= mylist[1]:
            size.append(50)
        elif item <= mylist[2]:
            size.append(100)
        elif item <= mylist[3]:
            size.append(150)
        elif item <= mylist[4]:
            size.append(200)
    return size

sizemap = sizeFunc(colorFunc(df["DEATHS"],5), df["DEATHS"])

# %%
image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

plt.scatter(longitude,latitude, s=sizemap, c=colormap)
plt.xlim(80,180)
plt.ylim(-70,30)
plt.title("Central South Pacific Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Central Pacific Earthquakes with Colormap on Earth.png")
plt.show()

# %%
image = plt.imread("plates.png")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

plt.scatter(longitude,latitude, s=sizemap, c=colormap)
plt.xlim(80,180)
plt.ylim(-70,30)
plt.title("Central South Pacific Earthquakes")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("Central Pacific Earthquakes with Colormap on Earth.png")
plt.show()
